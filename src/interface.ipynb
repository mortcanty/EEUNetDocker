# %% [markdown]
# # UNet Building Recognition with NAIP and SKYSAT Datasets (Trained with INRIA dataset)

# %%
import ee
ee.Authenticate()

# %%
from auxil.eeUnet_run import run
run()
# Out:
# Map(center=[37.26, -93.31], controls=(MeasureControl(options=['active_color', 'capture_z_index', 'completed_co…
# ...

# %%
ls
# Out:
# auxil/            Semantic_Segmentation.ipynb
# build/            Semantic_Segmentation_on_GEE_dev.ipynb
# dist/             Semantic_Segmentation_on_GEE_full.ipynb
# Dockerfile        setup.py
# generators.ipynb  tmp.jpg
# gradient.ipynb    tmp.jpg.aux.xml
# interface.ipynb   unet_inria_colab.ipynb
# MANIFEST          unet_inria_colabx.ipynb
# notebook.sh       unet_inria_colabxx.ipynb
# philly_test.tif   unet_inria_model4.h5
# prov_means.c      unet_lebedev_colab.ipynb
# scripts/

# %%
# %matplotlib inline

# %%
# %run scripts/dispms -f philly_naip.tif -p [1,2,3] -e 2 -d [250,250,1024,1024]

# %%
run scripts/unetclassify -m unet_inria_model4.h5 -d [250,250,1024,1024] philly_naip-tif
# Out:
# Error: __init__() got an unexpected keyword argument 'axis'
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~/python/EEUNetDocker/src/scripts/unetclassify.py in <module>
#     165
#     166 if __name__ == '__main__':
# --> 167     main()
#     168
#     169
#
# ~/python/EEUNetDocker/src/scripts/unetclassify.py in main()
#     146 #  write to disk
#     147     driver =  gdal.GetDriverByName('GTiff')
# --> 148     outDataset = driver.Create(outfile,xpatches*512,ypatches*512,1,GDT_Float32)
#     149     projection = inDataset.GetProjection()
#     150     geotransform = inDataset.GetGeoTransform()
#
# UnboundLocalError: local variable 'outfile' referenced before assignment
